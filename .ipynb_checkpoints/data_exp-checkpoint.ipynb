# %%
import sys
import pandas as pd
import nibabel
# Out:
# # packages in environment at /software/spackages/linux-centos8-x86_64/gcc-8.3.1/anaconda3-2019.10-v5cuhr6keyz5ryxcwvv2jkzfj2gwrj4a:
# #
# # Name                    Version                   Build  Channel
# _anaconda_depends         2019.10                  py37_0
# _ipyw_jlab_nb_ext_conf    0.1.0                    py37_0
# _libgcc_mutex             0.1                        main
# alabaster                 0.7.12                   py37_0
# anaconda                  custom                   py37_1
# anaconda-client           1.7.2                    py37_0
# anaconda-navigator        1.9.7                    py37_0
# anaconda-project          0.8.3                      py_0
# anyio                     2.2.0            py37h06a4308_1
# asn1crypto                1.0.1                    py37_0
# astroid                   2.3.1                    py37_0
# astropy                   3.2.2            py37h7b6447c_0
# atomicwrites              1.3.0                    py37_1
# ...

# %%
# !source activate skull
# !pip install nibabel
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/c3/f1/6e31b0287aed62233ec93535ac55554ec5e80c81b772b411e878c9d17179/nibabel-3.2.2-py3-none-any.whl
# ...
# ERROR: Could not install packages due to an EnvironmentError: [Errno 30] Read-only file system: '/software/spackages/linux-centos8-x86_64/gcc-8.3.1/anaconda3-2019.10-v5cuhr6keyz5ryxcwvv2jkzfj2gwrj4a/lib/python3.7/site-packages/nibabel'

# %%
test_load = nib.load('IXI002-Guys-0828-T1_bet_09.nii').get_fdata()
test_load.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d8fc7d29a942> in <module>
# ----> 1 test_load = nib.load('IXI002-Guys-0828-T1_bet_09.nii').get_fdata()
#       2 test_load.shape
#
# AttributeError: module 'babel' has no attribute 'load'

# %%
test = test_load[:,:,59]
plt.imshow(test)
plt.show()
